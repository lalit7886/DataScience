# %%
import pandas as pd 
import seaborn as sns
import numpy as np 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Titanic-Dataset.csv")

# %%
# How big is data?
df.shape
# Out:
# (891, 12)

# %%
#what data looks like?
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 606          607         0       3
# 182          183         0       3
# 505          506         0       1
# 531          532         0       3
# 200          201         0       3
#
#                                            Name   Sex   Age  SibSp  Parch  \
# 606                           Karaic, Mr. Milan  male  30.0      0      0
# 182       Asplund, Master. Clarence Gustaf Hugo  male   9.0      4      2
# 505  Penasco y Castellana, Mr. Victor de Satode  male  18.0      1      0
# 531                           Toufik, Mr. Nakli  male   NaN      0      0
# 200              Vande Walle, Mr. Nestor Cyriel  male  28.0      0      0
#
#        Ticket      Fare Cabin Embarked
# 606    349246    7.8958   NaN        S
# 182    347077   31.3875   NaN        S
# 505  PC 17758  108.9000   C65        C
# 531      2641    7.2292   NaN        C
# 200    345770    9.5000   NaN        S

# %%
# Whata is the datatype of the columns?
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Are any value are missing?
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Statical analysis of data..
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Are the value are duplicated?
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# corelation between feautere
a=df.corr(numeric_only=True)
plt.figure(figsize=(6,4))
sns.heatmap(a,annot=True)
plt.show()

# %%
categorical_type=df.select_dtypes(include="object").columns
numerical_type=df.select_dtypes(include=["int","float"]).columns

# %%
print(f"Categorical types are: {list(categorical_type)}")
print(f"Numerical types are: {list(numerical_type)}")
# Out:
# Categorical types are: ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']
# Numerical types are: ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
# Univariate Analysisi

df["Sex"].value_counts().plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
df["Embarked"].value_counts().plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
df["Survived"].value_counts().plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
df["Pclass"].value_counts().plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
df["SibSp"].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df["Parch"].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
sns.histplot(df["Age"],kde=True,stat='density')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
ax=sns.histplot(df["Fare"],kde=True,stat='density')
